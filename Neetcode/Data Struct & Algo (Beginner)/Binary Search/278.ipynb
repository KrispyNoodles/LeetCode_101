# %% [markdown]
# # 278. First Bad Version

# %%
# The isBadVersion API is already defined for you.
# def isBadVersion(version: int) -> bool:

# BRUTE FORCE (TLE as expected)
class Solution:
    def firstBadVersion(self, n: int) -> int:

        for value in range(1,n+1):

            if self.isBadVersion(value):
                return value

    def isBadVersion(self, num: int):
    
        secret_num = 4

        if num == secret_num:
            return True

        else:
            return False

# %%
# reodo
# The isBadVersion API is already defined for you.
# def isBadVersion(version: int) -> bool:

class Solution:
    def firstBadVersion(self, n: int) -> int:

        # calling the helper version till it finds the answer
        def helper(left, right):
            
            # this means that we have moved past and found the correct version
            if left > right:
                return left

            middle = (right+left)//2

            if not self.isBadVersion(middle):
                # this means we can search for version on the right of the middle
                return helper(middle+1, right)
            
            # this menas we have found a wokring version and we can search on the left of the version
            else:
                return helper(left, middle-1)

        return helper(1,n)
            


    def isBadVersion(self, num: int):
    
        secret_num = 4

        if num == secret_num:
            return True

        else:
            return False

# %%
# Input: 
n = 5
bad = 4

# Output: 4

# Explanation:
# call isBadVersion(3) -> false
# call isBadVersion(5) -> true
# call isBadVersion(4) -> true
# Then 4 is the first bad version.

sol = Solution()
sol.firstBadVersion(n)
# Out:
# 4
