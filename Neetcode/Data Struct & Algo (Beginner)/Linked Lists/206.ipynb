# %%
# Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
        
# creation of Nodes
ListNode1 = ListNode(1, None)
ListNode2 = ListNode(2, ListNode1)
ListNode3 = ListNode(3, ListNode2)
ListNode4 = ListNode(4, ListNode3)
ListNode5 = ListNode(5, ListNode4)

# %%
from typing import Optional

class Solution:
    def reverseList(self, head: Optional[ListNode]) -> Optional[ListNode]:

        # initilaising
        # current of what is being edited
        curr = head
        prev_ele = None

        while curr != None:

            # get the next_ele before reassigning
            next_ele = curr.next
            
            # reassign the curr
            curr.next = prev_ele

            # reassogn the prev_ele to be curr,
            # preparing for the next ele
            prev_ele = curr            

            # use the next_ele as the current
            curr = next_ele

        return prev_ele
    
    def view_link_list(self, head: Optional[ListNode]) -> Optional[ListNode]:

        print(head.val)

        curr = head

        while curr.next != None:

            curr = curr.next
            print(curr.val)

# %%
sol = Solution()
sol.view_link_list(ListNode1)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
sol = Solution()
sol.reverseList(ListNode5)
# Out:
# 5
# 4
# 3
# 2
# 1
