# %% [markdown]
# # 80. Remove Duplicates from Sorted Array II

# %%
from typing import List

class Solution:
    def removeDuplicates(self, nums: List[int]) -> int:
        
        # writer
        left = 2

        for i in range(2, len(nums)):

            # checking if it is the same as what 
            # has been written 2 steps back before
            if nums[i]!=nums[left-2]:
                
                nums[left] = nums[i]
                left+=1
            
            # write in 
            else:
                nums[left] = nums[i]
        
        return left

# time complexity of O(n)
# space of O(1)

# %%
sol = Solution()
nums = [0,0,1,1,1,1,2,3,3]

sol.removeDuplicates(nums)
# Out:
# [0, 1, 2, 3, 1, 1, 2, 3, 3]
# 4

# %%
sol = Solution()
nums = [1,1,1,2,2,3]

sol.removeDuplicates(nums)
# Out:
# [1, 1, 2, 2, 3, 3]
# 5
