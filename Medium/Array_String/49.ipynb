# %% [markdown]
# # 49. Group Anagrams

# %%
from typing import List

class Solution:
    def groupAnagrams(self, strs: List[str]) -> List[List[str]]:

        master_dict = {}
        counter = 1
        
        # creating a group of dics
        for string in strs:
            
            new_dict = {}

            for char in string:
                # try to retrieve for the char if not 0
                new_dict[char] = 1 + new_dict.get(char, 0)

            # add the dict in
            master_dict[counter] = new_dict
            
            # increment the counter
            counter+=1

        # adding into the master array now
        master_arr = []

# %%
string_1 = 'adcv'

# convert it into list then sort it
sort = sorted(string_1)
sort = "".join(sort)
sort
# Out:
# 'acdv'

# %%
a = list([0])
a.append(1)
a
# Out:
# [0, 1]

# %%
from typing import List

class Solution:
    def groupAnagrams(self, strs: List[str]) -> List[List[str]]:

        # creating a dict 
        # string: counter

        # empty map
        set_map = {}

        for index in range(len(strs)):

            # sort them first
            string = sorted(strs[index])
            string = "".join(string)
            
            # if it exist increment add the index in
            if string in set_map:
                set_map[string].append(index)
                set_map[string] = set_map[string]

            # empty 
            # create a new dict with its own index
            else:
                set_map[string] = [index]

        # returning the final array
        final_arr = []
        for values in set_map.values():
            temp_arr = []          

            # appending each into the arr
            for indexes in values:
                temp_arr.append(strs[indexes])

            final_arr.append(temp_arr)
        
        return final_arr

# N is the number of strings and K is the max length of each string
# time computation complexitty O(N*K*log(K))

# %%
sol = Solution()

# Input: 
strs = ["eat","tea","tan","ate","nat","bat"]
sol.groupAnagrams(strs)

# Output: [["bat"],["nat","tan"],["ate","eat","tea"]]
# Out:
# [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat']]

# %% [markdown]
# # shorter solns LOL

# %%
from typing import List
from collections import defaultdict

class Solution:
    def groupAnagrams(self, strs: List[str]) -> List[List[str]]:

        # creating a dict 
        # string: counter

        # empty map
        # if you try to acces a value that does exist it creates for you
        # the list is what is the datatype of the values
        set_map = defaultdict(list)

        for string in strs:

            # reordering the string
            sort = sorted(string)
            sort = "".join(sort)

            # append the string based on it's alphabetically sorted characters
            set_map[sort].append(string)
            
        return [i for i in set_map.values()]

# %%
sol = Solution()

# Input: 
strs = ["eat","tea","tan","ate","nat","bat"]
sol.groupAnagrams(strs)

# Output: [["bat"],["nat","tan"],["ate","eat","tea"]]
# Out:
# [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat']]
