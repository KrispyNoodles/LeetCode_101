# %% [markdown]
# # 973. K Closest Points to Origin

# %%
# solving using heap
import heapq
from typing import List

class Solution:
    def kClosest(self, points: List[List[int]], k: int) -> List[List[int]]:

        new_points = []

        # calculating the eculdian distance of each point
        for point in points:
            ecu_cal = point[0]*point[0] + point[1]*point[1] 
            new_points.append((ecu_cal, point))

        # creating a heap, 
        heapq.heapify(new_points)

        # answer
        answer = []

        # add in the answer based of k
        # since the smallest is what is being pop
        while len(answer)<k:
            temp = heapq.heappop(new_points)

            # append only the points
            answer.append(temp[1])

        return answer

# time complexity of O(n+klog(n))
# k is the number of elements in the points array and k is the number of closest points

# %%
# answer (HACKS wth...)
from typing import List

class Solution:
    # k contains how many nearest points needed
    def kClosest(self, points: List[List[int]], k: int) -> List[List[int]]:
        
        # because the sqrt with, or without doesnt affect which is largest
        points.sort(key=lambda x: x[0]**2 + x[1]**2)
        return points[:k]

# time complexity of O(nlog(n))

# %%
from typing import List
from collections import defaultdict
from math import sqrt

# there is no need to store the calculation then sort, it could be included into the lambda of the sort and worked directly with
class Solution:
    # k contains how many nearest points needed
    def kClosest(self, points: List[List[int]], k: int) -> List[List[int]]:
        
        # dict to store the points, and calculation of distance
        # it fails for repeated points
        new_dict = defaultdict()

        for a,b in points:
            # calcalation
            calc = sqrt(a*a+b*b)
            new_dict[(a,b)] = calc

        # reorder by points
        new_dict = sorted(new_dict.items(), key=lambda x:x[1])

        answer = []

        print(new_dict)

        for values, calc in new_dict:
            formatted_correctly = [values[0], values[1]]
            answer.append(formatted_correctly)

        return answer[:k]

# time complexity of O(nlog(n))

# %%
from typing import List
from collections import defaultdict
from math import sqrt

class Solution:
    # k contains how many nearest points needed
    def kClosest(self, points: List[List[int]], k: int) -> List[List[int]]:
        
        new_array = []

        for a,b in points:

            # calcalation
            calc = sqrt(a*a+b*b)

            new_point = [[a,b], calc]
            new_array.append(new_point)

        # sort
        new_array = sorted(new_array, key=lambda x: x[1])

        answer = []

        for point, cal in new_array:
            answer.append(point)

        return answer[:k]

# time complexity of O(nlog(n))

# %%
s = Solution()

# Input: 
points = [[2,2],[2,2],[3,3],[2,-2],[1,1]]
k = 4
# Output: [[1,1],[2,2],[2,2],[2,-2]]
s.kClosest(points, k)
# Out:
# [[1, 1], [2, 2], [2, 2], [2, -2]]

# %%
s = Solution()

# Input: 
points = [[3,3],[5,-1],[-2,4]]
k = 2
# Output: [[3,3],[-2,4]]
s.kClosest(points, k)
# Out:
# [[3, 3], [-2, 4]]
