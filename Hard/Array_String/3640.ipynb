# %% [markdown]
# # 3640. Trionic Array II

# %%
from typing import List

class Solution:
    def maxSumTrionic(self, nums: List[int]) -> int:

# %%
sol = Solution()

nums = [1,4,2,2,3,1,2]

sol.maxSumTrionic(nums)

# Ouput is 8
# Out:
# 8

# %%
sol = Solution()

nums = [0,-2,-1,-3,0,2,-1]

sol.maxSumTrionic(nums)

# Ouput is -4
# Out:
# -4

# %%
sol = Solution()

nums = [1,4,2,7]

sol.maxSumTrionic(nums)

# Ouput is 14
# Out:
# 14

# %%
sol = Solution()

nums =[0,-2,-1,-3,0,2,-1]

sol.maxSumTrionic(nums)

# (-2) + (-1) + (-3) + 0 + 2 = -4
# Out:
# -4
