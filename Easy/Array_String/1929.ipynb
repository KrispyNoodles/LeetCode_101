# %% [markdown]
# # 1929. Concatenation of Array
#
# ### Problem
# Given an integer array `nums` of length `n`, create an array `ans` of length `2n` such that:
#
# - `ans[i] = nums[i]`
# - `ans[i + n] = nums[i]` for all `0 <= i < n`
#
# In other words, `ans` is the **concatenation** of `nums` with itself.
# Return `ans`.
#
# ---
#
# ### Example 1
# **Input:** `nums = [1,2,1]` **Output:** `[1,2,1,1,2,1]`
#
# **Explanation:**
# `ans = [nums[0], nums[1], nums[2], nums[0], nums[1], nums[2]]`
# `ans = [1,2,1,1,2,1]`
#
# ---
#
# ### Example 2
# **Input:** `nums = [1,3,2,1]` **Output:** `[1,3,2,1,1,3,2,1]`
#
# **Explanation:**
# `ans = [nums[0], nums[1], nums[2], nums[3], nums[0], nums[1], nums[2], nums[3]]`
# `ans = [1,3,2,1,1,3,2,1]`
#
# ---
#
# ### Constraints
# - `n == nums.length`
# - `1 <= n <= 1000`
# - `1 <= nums[i] <= 1000`

# %% [markdown]
# # Exploration

# %%
from typing import List

# solution 1
class Solution:
    def getConcatenation(self, nums: List[int]) -> List[int]:

        return nums + nums

# %%
from typing import List

class Solution:
    def getConcatenation(self, nums: List[int]) -> List[int]:

        nums.extend(nums)
        return nums

        # reutrn nums.extend(nums) does not work and gives a null 
        # because nums.extend(nums) cnanot be reassigned but rather is a function working on nums

# %%
nums = [1,3,2,1]

s = Solution()
a = s.getConcatenation(nums)
a
# Output: [1,3,2,1,1,3,2,1]
# Out:
# [1, 3, 2, 1, 1, 3, 2, 1]

# %%
# why appending list does not work, because it will append everything into it

a = [1,3,2,1]
b = [4, 5]

a.append(b)
a
# Out:
# [1, 3, 2, 1, [4, 5]]

# %%
# Other solutions

a = [1,3,2,1]
b = [1,3,2,1]

# addition
print(a+b)

# multiplication works too on arrays
print(a*2)

# extention
a.extend(b)
print(a)

# This prints nothing because when extend is use, it is editing the list rather than creating a new list too
new = a.extend(b)
print(new)
# Out:
# [1, 3, 2, 1, 1, 3, 2, 1]
# [1, 3, 2, 1, 1, 3, 2, 1]
# [1, 3, 2, 1, 1, 3, 2, 1]
# None
